# %% [markdown]
# <a href="https://colab.research.google.com/github/OlgaShevel/Others/blob/main/!scruper_photo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Кастомный скрапер писался для выгрузки в colab фото с первой html-страницы Яндекс.картинки. Но может тянуть изображения и с некоторых других сайтов. Маркетплейсы и другие агрегаторы изображений ставят защиту или загружают фавиконы или угрозы.

# %% [markdown]
# **КАК УСТРОЕН**
#
# Работает по поисковому запросу в строке ресурса. В примере ниже загружены фото по запросу на русском языке "автомобиль Niva Нива". Можно писать на разных языках сколько угодно слов поиска (в разумных пределах, конечно).
#
# С учетом запроса ресурс сгенерирует адресную строку, которую надо скопировать и вставить в код.
#
# С первой html-страницы можно награбить в районе 200 фото. Если нобходимо грабить вторую, третью и т.д. страницы, достаточно внести соответствующие поправки руками в ссылку.
#
# По ходу работы скрапер прорежает временную папку colab, удаляя некондционные файлы, и дает статистику по количеству оставшихся.
#
# Через 3-4 запуска рекомендуется перегрузить скрапер - Яндекс тоже может выставить защиту.
#
# **ЧТО ДЕЛАЕТ**
#
# - тянет все форматы, которые сочтет изображением
# - выбирает уникальные ссылки для скачивания
# - игнорирует ошибки загрузки после первой попытки обращения к сайту хранения картинки
# - игнорирует ссылки больше 230 символов (они, как правило, выдают ошибки при скачивании)
# - раскладывает файлы по трем папкам в завсимости от размера (Big_over_2000px, Middle_500-2000px, Small_less_500px).
# - В названиях файлов также указывается размер картинки и далее через нижнюю несколько первых символов адреса сайта (например, "2048x1536_avtomob.jpg").
# - Папки с размерами зиппуются и автоматом скачиваются в папку загрузки компьютера (среда Windows, остальные операционки не пробовала).

# %%
# !pip install transliterate
# Out:
# Collecting transliterate
#   Downloading transliterate-1.10.2-py2.py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from transliterate) (1.16.0)
# Installing collected packages: transliterate
# Successfully installed transliterate-1.10.2

# %%
import requests
import re
import os
import zipfile
import random
import time
import shutil
import urllib.parse
import urllib.request
from transliterate import translit
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
from urllib.error import HTTPError
from PIL import Image

# Тут скачивается html-код сайта - soap ----------------------------------------
# Он дербанится на список ссылок - links

url = 'https://yandex.ru/images/search?text=%D0%B0%D0%B2%D1%82%D0%BE%D0%BC%D0%BE%D0%B1%D0%B8%D0%BB%D1%8C%20Niva%20%D0%9D%D0%B8%D0%B2%D0%B0'

parsed_url = urllib.parse.urlparse(url)
query_dict = urllib.parse.parse_qs(parsed_url.query)

# с get должно работать даже без ключа
text = urllib.parse.unquote(query_dict.get('text', [''])[0])
perem_rus = text.replace(' ', '_').title()
perem_rus = translit(text, 'ru', reversed=True)
perem_eng = perem_rus.replace(' ', '_').title()

if parsed_url.netloc != '':
  perem_rus = parsed_url.netloc.split('.')[0]
  perem_eng = translit(perem_rus, 'ru', reversed=True).replace(' ', '_').title()
else:
  query_dict = urllib.parse.parse_qs(parsed_url.query)
  text = urllib.parse.unquote(query_dict.get('text', [''])[0])
  perem_rus = text.replace(' ', '_').title()
  perem_eng = translit(perem_rus, 'ru', reversed=True).replace(' ', '_').title()

# Скачиваем html-код со ссылками -----------------------------------------------
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
#soup

spis_format = re.findall(r'[\'"](https[^\'" >]+\.(?:jpg|jpeg|gif|png))', str(soup))
unique_spis = set(spis_format)
formatted_spis = [f'{line}' for line in unique_spis]
links = formatted_spis
kol_all = len(links)

with open(f'Photo_{perem_eng}.txt', 'w') as f:
  f.write('\n'.join(links))

# Закачиваем ссылки img
# Тут ограничение по количеству попыток и времени коннекта с сервером-----------

import time
start_time = time.time()

# создаем папку и динамический path, чтобы он постоянно мог меняться------------
save_dir = f'Folder_{perem_eng}'
if not os.path.isdir(save_dir):
  os.makedirs(save_dir)
path = os.path.join('/content', save_dir)
if not os.path.exists(path):
    os.makedirs(path)

for i, ss in enumerate(links): # x это links
  ss = ss.strip()
  image_name = f'{ss.split("/")[-1]}'
  if len(image_name) <= 230:
    image_path = os.path.join(save_dir, image_name)
    # 1 - количество попыток соединения с сервером, если тот не отвечает
    for attempts in range(1):
      try:
        # 2 - количество секунд на каждую попытку
        response = requests.get(ss, timeout=2)
        with open(image_path, 'wb') as f:
          f.write(response.content)
        print(f'Успешно №{i+1} из {kol_all}: {image_name} from {ss}')
        #print(f'Успешно №{i+1}: {image_name} from {ss}')
        break # если загрузка прошла успешно, прерываем цикл попыток
      except (requests.exceptions.RequestException, requests.exceptions.Timeout) as e:
        print(f'Ошибка загрузки картинки с {ss} на попытке {attempts+1}: {e}')
        time.sleep(10) # пауза перед следующей попыткой
  else:
    print(f'Ссылка {ss} больше 230 символов')

t = int(time.time() - start_time)
print('\nКачалось {:02d} часов {:02d} минут {:02d} секунд'.format(t//3600, (t%3600)//60, t%60))

print()
print(f'Количество ссылок: \nизначально - {len(spis_format)} \nуникальных - {kol_all}')
print()

num_files = len([file for file in os.listdir(path) if os.path.isfile(os.path.join(path, file))])
print(f'\nВ папке "{perem_eng}" лежит {num_files} файлов')
# Out:
# Успешно №1 из 181: 1683392715_polinka-top-p-novaya-niva-kartinki-krasivo-36.jpg from https://polinka.top/uploads/posts/2023-05/1683392715_polinka-top-p-novaya-niva-kartinki-krasivo-36.jpg
# Успешно №2 из 181: vaz-2131-1995-33111sm.jpeg from https://driveboom.ru/gallery/vaz/photo/vaz-2131-1995-33111sm.jpeg
# Успешно №3 из 181: EMOWeSpW4AAfR9r.jpg from https://lh3.googleusercontent.com/-wRTULEmTuDg/YS2Zp09FHyI/AAAAAAACTL0/jcarZjIIRbs_hg9jjogWmO3-UNp-GgkMACLcBGAsYHQ/EMOWeSpW4AAfR9r.jpg
# Успешно №4 из 181: bc9d8058915f2cb43b3f67bf037625a3.jpg from https://i5.imageban.ru/thumbs/2018.11.18/bc9d8058915f2cb43b3f67bf037625a3.jpg
# Успешно №5 из 181: hqdefault.jpg from https://i.ytimg.com/vi/0BVpdNYKOZ0/hqdefault.jpg
# Успешно №6 из 181: urban-ziguli-niva-4x4.jpg from https://wallbox.ru/wallpapers/main2/201943/urban-ziguli-niva-4x4.jpg
# Успешно №7 из 181: avto_v_palto.jpg from https://zen-kanal.ru/upload/iblock/5dd/avto_v_palto.jpg
# Успешно №8 из 181: %D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5_2021-09-04_125316.jpg from https://daily-motor.ru/wp-content/uploads/2021/09/%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5_2021-09-04_125316.jpg
# Успешно №9 из 181: kr4n7lfxzlvgi_1yyt9ak.jpeg from https://ik.drivenn.ru/kr4n7lfxzlvgi_1yyt9ak.jpeg
# Успешно №10 из 181: e7f9d20930d43ef37fd961be4a4a.jpeg from https://i1.lbrd.ru/fileentry/get/210x210/15/80/e7f9d20930d43ef37fd961be4a4a.jpeg
# Успешно №11 из 181: _q_g48nBap8.jpg from https://sun9-76.userapi.com/impg/ULagHakMU7YwYQWlBwnzpEbzTOc7_-Y1nmbNlg/_q_g48nBap8.jpg
# Успешно №12 из 181: vaz-2121-12563.jpg from https://autodmir.ru/logo/1/12563/vaz-2121-12563.jpg
# Успешно №13 из 181: lada-niva-21213-1993-359466.jpg from https://www.mad4wheels.com/img/free-car-images/mobile/11374/lada-niva-21213-1993-359466.jpg
# Успешно №14 из 181: 1660737008_16-sportishka-com-p-lada-niva-kross-krasivo-foto-19.jpg from https://sportishka.com/uploads/posts/2022-08/thumbs/1660737008_16-sportishka-com-p-lada-niva-kross-krasivo-foto-19.jpg
# Успешно №15 из 181: 27765.jpg from https://www.avtorinok.ru/storage/news/pics/2015/27765.jpg
# Успешно №16 из 181: hqdefault.jpg from https://i.ytimg.com/vi/Vkii80RcYwg/hqdefault.jpg
# Успешно №17 из 181: 4578c63c84e8648ba422c5f76f51a333.jpg from https://i.pinimg.com/200x150/45/78/c6/4578c63c84e8648ba422c5f76f51a333.jpg
# Успешно №18 из 181: Lada%204x4%20Niva%20Grand%20Large.jpg from https://nashi-avto.ru/ru/vaz/2121/%D1%8D%D0%BA%D1%81/Lada%204x4%20Niva%20Grand%20Large.jpg
# Успешно №19 из 181: 17756.jpg from https://bycars.ru/upload/models/177/17756.jpg
# Успешно №20 из 181: 1660737008_16-sportishka-com-p-lada-niva-kross-krasivo-foto-19.jpg from https://sportishka.com/uploads/posts/2022-08/1660737008_16-sportishka-com-p-lada-niva-kross-krasivo-foto-19.jpg
# Успешно №21 из 181: bc8a4b7da86c06d3d90b5dad73f437d6.jpeg from https://arhmez.ru/wp-content/uploads/b/c/8/bc8a4b7da86c06d3d90b5dad73f437d6.jpeg
# Успешно №22 из 181: 82880760_125310715424921_7758139992118064776_n.jpg from https://scontent-hel3-1.cdninstagram.com/v/t51.2885-15/e35/82880760_125310715424921_7758139992118064776_n.jpg
# Успешно №23 из 181: AQABrJk5LNHE50HayxfgtbJxnExnCDxYTZCFuPMQgW7zhmLpT8bonFCoH_o5tOq-S16-cA4M7iGB82hVIbWQwX3yJRE.jpg from https://resizer.mail.ru/p/24373fc8-d19e-5e78-b0eb-06b6dcb29121/AQABrJk5LNHE50HayxfgtbJxnExnCDxYTZCFuPMQgW7zhmLpT8bonFCoH_o5tOq-S16-cA4M7iGB82hVIbWQwX3yJRE.jpg
# Успешно №24 из 181: cF3pMxgzIVcEGuWt1Z6kVA.jpg from https://irecommend.ru/sites/default/files/product-images/36303/cF3pMxgzIVcEGuWt1Z6kVA.jpg
# Успешно №25 из 181: lada-21214-050-10_lada_4_4_standart.jpg from https://s38.wheelsage.org/format/picture/picture-thumb-medium/l/lada/21214-050-10_4_4_standart/lada-21214-050-10_lada_4_4_standart.jpg
# Успешно №26 из 181: nMGTb3BtuuI.jpg from https://sun9-31.userapi.com/impf/c852036/v852036846/e673e/nMGTb3BtuuI.jpg
# Успешно №27 из 181: maxresdefault.jpg from https://i.ytimg.com/vi/tV07ATPpoho/maxresdefault.jpg
# Успешно №28 из 181: 63a4565837b27d6da36e0576-1.jpg from https://cdn0.youla.io/files/images/720_720_out/63/a4/63a4565837b27d6da36e0576-1.jpg
# Успешно №29 из 181: sovetskij-vnedorozhnik-Niva.jpg from https://perevozki-stolitsa.ru/wp-content/uploads/2020/11/sovetskij-vnedorozhnik-Niva.jpg
# Успешно №30 из 181: 3521784.jpg from https://fb.ru/misc/i/gallery/258510/3521784.jpg
# Успешно №31 из 181: 388852-mashina-niva-6.jpg from https://img.razrisyika.ru/kart/98/1200/388852-mashina-niva-6.jpg
# Успешно №32 из 181: 2135.jpg from https://borovichi.explorer-russia.ru/gallery/auto/body/2135.jpg
# Успешно №33 из 181: 1635213175_50-hdpic-club-p-mashina-niva-77.jpg from https://hdpic.club/uploads/posts/2021-10/1635213175_50-hdpic-club-p-mashina-niva-77.jpg
# Успешно №34 из 181: lada-niva-4x4-21212-1983-359462.jpg from https://www.mad4wheels.com/img/free-car-images/mobile/11372/lada-niva-4x4-21212-1983-359462.jpg
# Успешно №35 из 181: 363957-lada-niva-3.jpg from https://img.razrisyika.ru/kart/91/363957-lada-niva-3.jpg
# Успешно №36 из 181: 1701914011_sportishka-com-p-niva-tsveta-khaki-krasivo-36.jpg from https://sportishka.com/uploads/posts/2023-12/1701914011_sportishka-com-p-niva-tsveta-khaki-krasivo-36.jpg
# Успешно №37 из 181: Lada-4x4.-Foto-Lada-1.jpg from https://avtonovostidnya.ru/wp-content/uploads/2018/04/Lada-4x4.-Foto-Lada-1.jpg
# Ошибка загрузки картинки с https://scontent-arn2-2.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/135045934_3382146278574888_5116122310386870481_n.jpg на попытке 1: HTTPSConnectionPool(host='scontent-arn2-2.cdninstagram.com', port=443): Max retries exceeded with url: /v/t51.2885-15/e35/s1080x1080/135045934_3382146278574888_5116122310386870481_n.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7992b39c62f0>: Failed to resolve 'scontent-arn2-2.cdninstagram.com' ([Errno -2] Name or service not known)"))
# Успешно №39 из 181: 1578753433_goa.jpg from https://saintbasil.ru/img.php?ipt=https://versiya.info/uploads/posts/2020-01/medium/1578753433_goa.jpg
# Успешно №40 из 181: sddefault.jpg from https://i.ytimg.com/vi/584letEQeFo/sddefault.jpg
# Успешно №41 из 181: maxresdefault.jpg from https://i.ytimg.com/vi/aoMLM9Qq_T4/maxresdefault.jpg
# Успешно №42 из 181: a5d85fa83f0c205ad130f0c9f31ba14a04bd1c87.jpg from https://motor.ru/imgs/2022/12/26/22/5731028/a5d85fa83f0c205ad130f0c9f31ba14a04bd1c87.jpg
# Успешно №43 из 181: 1701356924_sportishka-com-p-niva-vid-speredi-pinterest-1.jpg from https://sportishka.com/uploads/posts/2023-11/1701356924_sportishka-com-p-niva-vid-speredi-pinterest-1.jpg
# Успешно №44 из 181: maxresdefault.jpg from https://i.ytimg.com/vi/nO5mDzEyNis/maxresdefault.jpg
# Успешно №45 из 181: 0-1496.jpg from https://modelist-konstruktor.org/wp-content/uploads/2018/07/0-1496.jpg
# Успешно №46 из 181: fchtn1z0qijhf_1gdxcyi.jpeg from https://if.drivenn.ru/fchtn1z0qijhf_1gdxcyi.jpeg
# Успешно №47 из 181: 6e74209s-1920.jpg from https://a.d-cd.net/6e74209s-1920.jpg
# Успешно №48 из 181: 388865-mashina-niva-19.jpg from https://img.razrisyika.ru/kart/98/388865-mashina-niva-19.jpg
# Успешно №49 из 181: OxfNdNs1.jpg from https://avtoexperts.ru/wp-content/uploads/OxfNdNs1.jpg
# Ошибка загрузки картинки с https://autotema.org.ua/wp-content/uploads/1679305a78d37cc911da48089ab4a01a.jpg на попытке 1: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Успешно №51 из 181: avtomobili-vaz-niva-1027492.jpg from https://yamtro.ru/800/600/https/i.artfile.me/wallpaper/13-04-2016/1920x1080/avtomobili-vaz-niva-1027492.jpg
# Успешно №52 из 181: 0_10a29d_cf49a1ae_XXL.jpg from https://img-fotki.yandex.ru/get/49649/15649173.292/0_10a29d_cf49a1ae_XXL.jpg
# Успешно №53 из 181: hqdefault.jpg from https://i.ytimg.com/vi/ypev3AaHPgw/hqdefault.jpg
# Успешно №54 из 181: 1660800367_5-sportishka-com-p-niva-taiga-novaya-krasivo-foto-5.jpg from https://sportishka.com/uploads/posts/2022-08/1660800367_5-sportishka-com-p-niva-taiga-novaya-krasivo-foto-5.jpg
# Успешно №55 из 181: 30e4c90bf38a3653f6bf9012cbffffbd.jpg from https://carsweek.ru/upload/resize_cache/iblock/30e/870_400_2/30e4c90bf38a3653f6bf9012cbffffbd.jpg
# Успешно №56 из 181: IMG_20210804_132949.jpg from https://abkhaz-auto.ru/ii/660/054/original/IMG_20210804_132949.jpg
# Успешно №57 из 181: 388847-mashina-niva-1.jpg from https://img.razrisyika.ru/kart/98/1200/388847-mashina-niva-1.jpg
# Успешно №58 из 181: d31WILtEzTvqAAxDg6NjbhHVyh4dK8D_tTRlaNLckE3Y4mm5K6EtbbwcazysHRqO22avYin3__xybuzvVHAhvjqP.jpg from https://sun9-26.userapi.com/s/v1/ig2/d31WILtEzTvqAAxDg6NjbhHVyh4dK8D_tTRlaNLckE3Y4mm5K6EtbbwcazysHRqO22avYin3__xybuzvVHAhvjqP.jpg
# Успешно №59 из 181: 5a9de423a09cd55a2e474e96.jpg from https://cache3.youla.io/files/images/720_720_out/5a/9d/5a9de423a09cd55a2e474e96.jpg
# Успешно №60 из 181: VJwFO522dCI.jpg from https://sun9-28.userapi.com/impf/c841324/v841324717/68336/VJwFO522dCI.jpg
# Успешно №61 из 181: lada_vaz_2121_4x4_2.jpg from https://avtomotospec.ru/wp-content/uploads/lada_vaz_2121_4x4_2.jpg
# Успешно №62 из 181: 8uh9mhp2eJ0.jpg from https://sun9-10.userapi.com/impg/wU1uuObPSE5EbYbW5TzxoRqVdec_oLJfUG2RCg/8uh9mhp2eJ0.jpg
# Успешно №63 из 181: 1479463868_img_8178.jpg from https://omsklada.ru/fotos/about/1479463868_img_8178.jpg
# Успешно №64 из 181: %D0%9D%D0%98%D0%92%D0%90_2121.jpg from https://image.moly-shop.ru/files/1/6667/1980939/original/%D0%9D%D0%98%D0%92%D0%90_2121.jpg
# Успешно №65 из 181: 1b1d43bf8e72c79ba1313566294b797e6c860aa9_full.jpg from https://avatars.akamai.steamstatic.com/1b1d43bf8e72c79ba1313566294b797e6c860aa9_full.jpg
# Ошибка загрузки картинки с https://www.kolesa.ru/uploads/bnnews/2014/10/22/64514fe7b9a05b2f645dc67281c1ee1e.jpg на попытке 1: HTTPSConnectionPool(host='www.kolesa.ru', port=443): Read timed out. (read timeout=2)
# Успешно №67 из 181: 388870-mashina-niva-24.jpg from https://img.razrisyika.ru/kart/98/388870-mashina-niva-24.jpg
# Успешно №68 из 181: 057d1e804a0ef8a88db55579c73bf528.jpeg from https://arhmez.ru/wp-content/uploads/0/5/7/057d1e804a0ef8a88db55579c73bf528.jpeg
# Успешно №69 из 181: nedir-ne-degildir.jpg from https://www.nivaturkiye.com/TR/wp-content/uploads/2016/01/nedir-ne-degildir.jpg
# Успешно №70 из 181: c64bb01s-1920.jpg from https://a.d-cd.net/c64bb01s-1920.jpg
# Успешно №71 из 181: 38bf24f206b379aa38df9bffe2bd26f8.jpeg from https://mn365.ru/wp-content/uploads/2022/04/38bf24f206b379aa38df9bffe2bd26f8.jpeg
# Ошибка загрузки картинки с https://myskillsconnect.com/uploads/posts/2023-06/1686141815_myskillsconnect-com-p-foto-vsekh-modelei-vaz-niva-5.jpg на попытке 1: HTTPSConnectionPool(host='myskillsconnect.com', port=443): Max retries exceeded with url: /uploads/posts/2023-06/1686141815_myskillsconnect-com-p-foto-vsekh-modelei-vaz-niva-5.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# Успешно №73 из 181: 1635213143_41-hdpic-club-p-mashina-niva-64.jpg from https://hdpic.club/uploads/posts/2021-10/1635213143_41-hdpic-club-p-mashina-niva-64.jpg
# Успешно №74 из 181: 1-1.jpeg from https://xtoplivo.ru/wp-content/uploads/2018/10/1-1.jpeg
# Успешно №75 из 181: swmEl3LtVIBuAG4SEC6zUYmotHs-1920.jpg from https://a.d-cd.net/swmEl3LtVIBuAG4SEC6zUYmotHs-1920.jpg
# Успешно №76 из 181: a5c8f09f9a4c715b4ffb0f860192b6c1.jpeg from https://horse-h.ru/wp-content/uploads/a/5/c/a5c8f09f9a4c715b4ffb0f860192b6c1.jpeg
# Успешно №77 из 181: harakteristiki-vaz-2121-4x4-1977-17-21219-mt-3dr-sport-coupe-516d0ed.jpg from https://transkomplect.ru/wp-content/uploads/2023/02/harakteristiki-vaz-2121-4x4-1977-17-21219-mt-3dr-sport-coupe-516d0ed.jpg
# Ошибка загрузки картинки с https://finobzor.ru/uploads/posts/2017-12/1512933612_lada-4x4-niva-taiga-im-test-in-den-vogesen-im-elsass-frankreich-lada-kommt-ueberall-durch-guenstigster-suv-offroad-automativ-46.jpg на попытке 1: HTTPSConnectionPool(host='finobzor.ru', port=443): Read timed out. (read timeout=2)
# Успешно №79 из 181: 1683409958_kartinkof-club-p-kartinki-mashina-niva-18.jpg from https://kartinkof.club/uploads/posts/2023-05/1683409958_kartinkof-club-p-kartinki-mashina-niva-18.jpg
# Успешно №80 из 181: 7639be0037da8b60cdb7966cfeec0a7e.jpg from https://i.pinimg.com/736x/76/39/be/7639be0037da8b60cdb7966cfeec0a7e.jpg
# Успешно №81 из 181: bp.jpeg from https://r1.mt.ru/r2/photo3C42/20977900313-0/jpg/bp.jpeg
# Успешно №82 из 181: 7-rossijskih-brendov-kotorye-stali-legendoj-dlya-vsego-mira-2-5.jpg from https://molva33.ru/wp-content/uploads/2019/09/7-rossijskih-brendov-kotorye-stali-legendoj-dlya-vsego-mira-2-5.jpg
# Успешно №83 из 181: 2967967452.jpg from https://i06.fotocdn.net/s132/9c442065e0c4cff7/public_pin_l/2967967452.jpg
# Успешно №84 из 181: hqdefault.jpg from https://i.ytimg.com/vi/4pGZhMMV4cM/hqdefault.jpg
# Успешно №85 из 181: 23823585_132831120759032_8943990891060658176_n.jpg from https://scontent-ams4-1.cdninstagram.com/v/t51.2885-15/e35/23823585_132831120759032_8943990891060658176_n.jpg
# Успешно №86 из 181: 9bb3dc3d5188fd2554339f292af92c2c.jpeg from https://kuznitsaspb.ru/wp-content/uploads/9/b/b/9bb3dc3d5188fd2554339f292af92c2c.jpeg
# Успешно №87 из 181: bbe4601bfd75bb01dcb43cff1c83ffb3.jpeg from https://www.innov.ru/upload/iblock/bbe/bbe4601bfd75bb01dcb43cff1c83ffb3.jpeg
# Успешно №88 из 181: 3606bd4fdd8936a02bf005341d6156cc--x-pictures.jpg from https://i.pinimg.com/236x/36/06/bd/3606bd4fdd8936a02bf005341d6156cc--x-pictures.jpg
# Успешно №89 из 181: img_id156766647365861750.jpeg from https://avatars.mds.yandex.net/get-mpic/4219717/img_id156766647365861750.jpeg
# Успешно №90 из 181: 1544451223_lada_niva_005.jpg from https://www.vladtime.ru/uploads/posts/2018-12/thumbs/1544451223_lada_niva_005.jpg
# Ошибка загрузки картинки с https://zolya.ru/wp-content/uploads/1/9/2/192ad2aeeea3a449034cf4a03390cd15.jpeg на попытке 1: HTTPSConnectionPool(host='zolya.ru', port=443): Max retries exceeded with url: /wp-content/uploads/1/9/2/192ad2aeeea3a449034cf4a03390cd15.jpeg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7992b39c76a0>: Failed to resolve 'zolya.ru' ([Errno -2] Name or service not known)"))
# Успешно №92 из 181: 62d55c4e.jpg from https://carakoom.com/data/wall/787/62d55c4e.jpg
# Успешно №93 из 181: 1680351707_maina-club-p-niva-sovetskii-vnedorozhnik-krasivo-70.jpg from https://maina.club/uploads/posts/2023-04/1680351707_maina-club-p-niva-sovetskii-vnedorozhnik-krasivo-70.jpg
# Успешно №94 из 181: 45d006c555a004047e7befa544ad544b.jpg from https://i.pinimg.com/236x/45/d0/06/45d006c555a004047e7befa544ad544b.jpg
# Успешно №95 из 181: 32735112.jpg from https://umeha.3dn.ru/_pu/85/32735112.jpg
# Успешно №96 из 181: sddefault.jpg from https://i.ytimg.com/vi/zcPQMqiwwAk/sddefault.jpg
# Успешно №97 из 181: ba4fb8b397b7f372fd05da3ea3d34286.jpeg from https://aybaz.ru/wp-content/uploads/b/a/4/ba4fb8b397b7f372fd05da3ea3d34286.jpeg
# Успешно №98 из 181: 1b4789dd4f4e1326328361e01a0b6f34.jpg from https://carsweek.ru/upload/iblock/1b4/1b4789dd4f4e1326328361e01a0b6f34.jpg
# Успешно №99 из 181: 418834-niva-4h4-8.jpg from https://img.razrisyika.ru/kart/105/1200/418834-niva-4h4-8.jpg
# Успешно №100 из 181: c67f4087449afbf17a5b5f2e03c88697.jpg from https://u2.9111s.ru/uploads/202308/30/c67f4087449afbf17a5b5f2e03c88697.jpg
# Успешно №101 из 181: 258882422_409863040774563_3555790101885103950_n.webp.jpg from https://scontent-hel3-1.cdninstagram.com/v/t51.2885-15/e35/258882422_409863040774563_3555790101885103950_n.webp.jpg
# Успешно №102 из 181: exmpl_lada-1-1-1536x1536.jpg from https://s8.stc.all.kpcdn.net/russia/wp-content/uploads/2020/03/exmpl_lada-1-1-1536x1536.jpg
# Успешно №103 из 181: 978.jpg from https://newsbuzz.ru/wp-content/uploads/2018/01/978.jpg
# Успешно №104 из 181: 1696526051_gas-kvas-com-p-kartinki-niva-6.jpg from https://gas-kvas.com/grafic/uploads/posts/2023-10/1696526051_gas-kvas-com-p-kartinki-niva-6.jpg
# Успешно №105 из 181: 1540230536_181022171608_600x400.jpg from https://zamin.uz/uploads/posts/2018-10/1540230536_181022171608_600x400.jpg
# Успешно №106 из 181: original.jpg from https://yamtro.ru/800/600/https/mtdata.ru/u22/photo4D25/20849836116-0/original.jpg
# Успешно №107 из 181: original.jpg from https://mtdata.ru/u13/photoE757/20485581942-0/original.jpg
# Успешно №108 из 181: 1690461332_hdpic-club-p-niva-urban-4.jpg from https://hdpic.club/photo/uploads/posts/2023-07/1690461332_hdpic-club-p-niva-urban-4.jpg
# Успешно №109 из 181: avtomobili-vaz-niva-1027492.jpg from https://i.artfile.me/wallpaper/13-04-2016/2048x1536/avtomobili-vaz-niva-1027492.jpg
# Успешно №110 из 181: 1696526059_gas-kvas-com-p-kartinki-niva-43.jpg from https://gas-kvas.com/grafic/uploads/posts/2023-10/1696526059_gas-kvas-com-p-kartinki-niva-43.jpg
# Успешно №111 из 181: Lada%20Urban.jpg from https://abc-auto.ru/news/images/addition2/Lada%20Urban.jpg
# Успешно №112 из 181: 1458379226_1.jpg from https://gibdd.net.ru/wp-content/uploads/2016/03/1458379226_1.jpg
# Успешно №113 из 181: 1701190909_sportishka-com-p-belaya-niva-vkontakte-10.jpg from https://sportishka.com/uploads/posts/2023-11/1701190909_sportishka-com-p-belaya-niva-vkontakte-10.jpg
# Успешно №114 из 181: 1545805055_1528139795110993855.jpg from https://www.vladtime.ru/uploads/posts/2018-12/1545805055_1528139795110993855.jpg
# Успешно №115 из 181: 1635213133_4-hdpic-club-p-mashina-niva-8.jpg from https://hdpic.club/uploads/posts/2021-10/thumbs/1635213133_4-hdpic-club-p-mashina-niva-8.jpg
# Успешно №116 из 181: lada-4x4-3d-089.jpg from https://kolesa-uploads.ru/-/05fb4e00-8ccc-4f78-81e9-017e1273c5f9/lada-4x4-3d-089.jpg
# Успешно №117 из 181: 108.jpg from https://koloritno.info/photo/108.jpg
# Успешно №118 из 181: 1667539504_8-sportishka-com-p-lada-urban-instagram-8.jpg from https://sportishka.com/uploads/posts/2022-11/thumbs/1667539504_8-sportishka-com-p-lada-urban-instagram-8.jpg
# Ошибка загрузки картинки с https://myskillsconnect.com/uploads/posts/2023-07/1689247445_myskillsconnect-com-p-niva-shevrole-urban-foto-10.jpg на попытке 1: HTTPSConnectionPool(host='myskillsconnect.com', port=443): Max retries exceeded with url: /uploads/posts/2023-07/1689247445_myskillsconnect-com-p-niva-shevrole-urban-foto-10.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# Успешно №120 из 181: eR56EnVv_toW3z1gZ4UVDJTcRL-nQasJ_cQcu0AiVDtGgsVK8JxmzPW3e47-im02gPUjttO1qs75wPx1f4wlNSvy.jpg from https://sun9-39.userapi.com/s/v1/ig2/eR56EnVv_toW3z1gZ4UVDJTcRL-nQasJ_cQcu0AiVDtGgsVK8JxmzPW3e47-im02gPUjttO1qs75wPx1f4wlNSvy.jpg
# Ошибка загрузки картинки с https://autogpbl.ru/upload/delight.webpconverter/upload/automarket/c2c/cpyrwdcrfg97dyegzvdk9m4vl2hnp1kn.jpg на попытке 1: HTTPSConnectionPool(host='autogpbl.ru', port=443): Max retries exceeded with url: /upload/delight.webpconverter/upload/automarket/c2c/cpyrwdcrfg97dyegzvdk9m4vl2hnp1kn.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# Успешно №122 из 181: default_6431ac4feb38fc3804d7dfd4da15feb2.jpg from https://s.auto.drom.ru/i24244/m/bull_image_stub/default_6431ac4feb38fc3804d7dfd4da15feb2.jpg
# Успешно №123 из 181: 1651231203_12-sportishka-com-p-lada-niva-urban-mashini-krasivo-foto-13.jpg from https://sportishka.com/uploads/posts/2022-04/1651231203_12-sportishka-com-p-lada-niva-urban-mashini-krasivo-foto-13.jpg
# Успешно №124 из 181: 2fce7e860d4a36ddbfd083c480d8822b.jpg from https://u2.9111s.ru/uploads/202311/01/2fce7e860d4a36ddbfd083c480d8822b.jpg
# Успешно №125 из 181: vEjljGwq6DI.jpg from https://sun9-73.userapi.com/impg/dS9KtS8hn3aE42srNE8sKvGZgxXMEqbR8chcNg/vEjljGwq6DI.jpg
# Успешно №126 из 181: daafcbbfc96a8359ed19d351dbde968e.jpg from https://i.trse.ru/2016/02/daafcbbfc96a8359ed19d351dbde968e.jpg
# Успешно №127 из 181: 8280613074.jpg from https://74.img.avito.st/208x156/8280613074.jpg
# Успешно №128 из 181: bp.jpeg from https://r2.mt.ru/r1/photo3D2B/20321417819-0/jpg/bp.jpeg
# Успешно №129 из 181: tmAAAgLBIeA-1920.jpg from https://a.d-cd.net/tmAAAgLBIeA-1920.jpg
# Успешно №130 из 181: avtomobili-vaz-lada-niva-21213-lada-niva-148187.jpg from https://i.artfile.me/wallpaper/04-04-2011/2048x1536/avtomobili-vaz-lada-niva-21213-lada-niva-148187.jpg
# Успешно №131 из 181: original.jpg from https://s.mediasalt.ru/images/349/349552/original.jpg
# Успешно №132 из 181: Lada-4x4.-Foto-Lada-1-1536x960.jpg from https://avtonovostidnya.ru/wp-content/uploads/2018/04/Lada-4x4.-Foto-Lada-1-1536x960.jpg
# Успешно №133 из 181: vaz-181.jpg from https://megaprokat.kz/images/auto/vaz-181.jpg
# Успешно №134 из 181: 1491563866_lada-4x4-niva-taiga-im-test-in-den-vogesen-im-elsass-frankreich-lada-kommt-ueberall-durch-guenstigster-suv-offroad-automativ-46.jpg from https://1gai.ru/uploads/posts/2017-04/1491563866_lada-4x4-niva-taiga-im-test-in-den-vogesen-im-elsass-frankreich-lada-kommt-ueberall-durch-guenstigster-suv-offroad-automativ-46.jpg
# Успешно №135 из 181: lada-44-export-edition-2010nv.jpeg from https://images.thepage.ua/storage/182891/lada-44-export-edition-2010nv.jpeg
# Успешно №136 из 181: wClAPXJmEOA.jpg from https://sun9-38.userapi.com/impg/54hVRpK6MwAALABdgakMt9EC9EpnAChVX5vCJQ/wClAPXJmEOA.jpg
# Успешно №137 из 181: 1541611408_435c9e54.jpeg from https://www.vladtime.ru/uploads/posts/2018-11/1541611408_435c9e54.jpeg
# Успешно №138 из 181: 0607b05defb07f301886cac677473fc5.jpg from https://retell.info/wp-content/uploads/2018/12/0607b05defb07f301886cac677473fc5.jpg
# Успешно №139 из 181: e7b5769s-1920.jpg from https://a.d-cd.net/e7b5769s-1920.jpg
# Успешно №140 из 181: 363965-lada-niva-11.jpg from https://img.razrisyika.ru/kart/91/363965-lada-niva-11.jpg
# Успешно №141 из 181: 1667560554_35-sportishka-com-p-lada-niva-blek-krasivo-35.jpg from https://sportishka.com/uploads/posts/2022-11/1667560554_35-sportishka-com-p-lada-niva-blek-krasivo-35.jpg
# Успешно №142 из 181: 20140225032834254f.jpg from https://110km.ru/attachment/8d146945a26ec6d15ababde648dddbcc8f994209/20140225032834254f.jpg
# Успешно №143 из 181: 829aa5fe3e183447c5353a028b900b8d--cars--black-cars.jpg from https://i.pinimg.com/736x/82/9a/a5/829aa5fe3e183447c5353a028b900b8d--cars--black-cars.jpg
# Успешно №144 из 181: 196219880_4281357151895899_4815316925796892081_n.jpg from https://scontent-hel3-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/196219880_4281357151895899_4815316925796892081_n.jpg
# Успешно №145 из 181: %D0%B2%D0%B0%D0%B7-21212.jpg from https://nashi-avto.ru/ru/vaz/2121/%D0%B2%D0%B0%D0%B7-21212.jpg
# Успешно №146 из 181: 418856-niva-4h4-30.jpg from https://img.razrisyika.ru/kart/105/1200/418856-niva-4h4-30.jpg
# Успешно №147 из 181: original.jpg from https://cdn.matador.tech/source/gallery/6298/6907/original.jpg
# Успешно №148 из 181: a61c0596ec835fdc9b74546eee804d38.jpeg from https://www.sberleasing.ru/upload/iblock/76b/vjfzni6e6bg0585uhgfynisawvpq89b5/a61c0596ec835fdc9b74546eee804d38.jpeg
# Успешно №149 из 181: hqdefault.jpg from https://i.ytimg.com/vi/cltXh2gGWHc/hqdefault.jpg
# Успешно №150 из 181: wallpapers_vaz_niva_1977_1_800x600.jpg from https://img.favcars.com/vaz/niva/wallpapers_vaz_niva_1977_1_800x600.jpg
# Успешно №151 из 181: wwAAAgJJ3uA-1920.jpg from https://a.d-cd.net/wwAAAgJJ3uA-1920.jpg
# Успешно №152 из 181: 1635213147_5-hdpic-club-p-mashina-niva-9.jpg from https://hdpic.club/uploads/posts/2021-10/1635213147_5-hdpic-club-p-mashina-niva-9.jpg
# Успешно №153 из 181: 1479463868_img_8178-1536x960.jpeg from https://avto-oblast.ru/wp-content/uploads/2022/11/1479463868_img_8178-1536x960.jpeg
# Успешно №154 из 181: fixed1480x800_248197b6632540c0e59b7f220a391bda.jpg from https://avto-babilon.a1sc.ru/uploads/news/image/131159/fixed1480x800_248197b6632540c0e59b7f220a391bda.jpg
# Успешно №155 из 181: 484c60cc2ffbedc18c8fd2de995af617.jpeg from https://aybaz.ru/wp-content/uploads/4/8/4/484c60cc2ffbedc18c8fd2de995af617.jpeg
# Успешно №156 из 181: 1680080772_maina-club-p-mashina-lada-niva-krasivo-47.jpg from https://maina.club/uploads/posts/2023-03/1680080772_maina-club-p-mashina-lada-niva-krasivo-47.jpg
# Успешно №157 из 181: Lada_Russian_cars_2014_490350.jpg from https://s1.1zoom.me/big3/589/Lada_Russian_cars_2014_490350.jpg
# Успешно №158 из 181: lada_niva_bronto_1044290.jpg from https://s.auto.drom.ru/i24264/c/photos/fullsize/lada/niva_bronto/lada_niva_bronto_1044290.jpg
# Успешно №159 из 181: ada9a09acea936d776a6f55c82778c43_XL.jpg from https://www.lada-vesta2.ru/media/k2/items/cache/ada9a09acea936d776a6f55c82778c43_XL.jpg
# Успешно №160 из 181: 1_PRCH.jpg from https://images.kienthuc.net.vn/zoom/800/Uploaded/nguyenanhtuan/2018_04_20/lada/1_PRCH.jpg
# Успешно №161 из 181: hqdefault.jpg from https://i.ytimg.com/vi/YptSKjjRQMI/hqdefault.jpg
# Успешно №162 из 181: dPvwxR7-foVr4UKYT-EHhZ6lDdE-1920.jpg from https://a.d-cd.net/dPvwxR7-foVr4UKYT-EHhZ6lDdE-1920.jpg
# Успешно №163 из 181: uk-virobnictvo-lada-4x4-urban-bude-zapuseno-20-kvitna-1.jpg from https://offroad.net.ua/wp-content/uploads/2020/02/uk-virobnictvo-lada-4x4-urban-bude-zapuseno-20-kvitna-1.jpg
# Успешно №164 из 181: 1696526053_gas-kvas-com-p-kartinki-niva-15.jpg from https://gas-kvas.com/grafic/uploads/posts/2023-10/1696526053_gas-kvas-com-p-kartinki-niva-15.jpg
# Успешно №165 из 181: 1574606858_50e70eb76e1f01d8.jpg from https://versiya.info/uploads/posts/2019-11/1574606858_50e70eb76e1f01d8.jpg
# Успешно №166 из 181: 1683409964_kartinkof-club-p-kartinki-mashina-niva-32.jpg from https://kartinkof.club/uploads/posts/2023-05/1683409964_kartinkof-club-p-kartinki-mashina-niva-32.jpg
# Ошибка загрузки картинки с https://myskillsconnect.com/uploads/posts/2023-06/1686905580_myskillsconnect-com-p-avtomobil-niva-foto-1.jpg на попытке 1: HTTPSConnectionPool(host='myskillsconnect.com', port=443): Max retries exceeded with url: /uploads/posts/2023-06/1686905580_myskillsconnect-com-p-avtomobil-niva-foto-1.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# Успешно №168 из 181: chto-luchshe-vaz-niva-ili-shevrole-niva-obzor.jpg from https://ladaautos.ru/wp-content/uploads/2017/03/chto-luchshe-vaz-niva-ili-shevrole-niva-obzor.jpg
# Успешно №169 из 181: 155_lada.jpg from https://fered.ru/images/Lada/001-200/155_lada.jpg
# Успешно №170 из 181: 1660800394_21-sportishka-com-p-niva-taiga-novaya-krasivo-foto-33.jpg from https://sportishka.com/uploads/posts/2022-08/1660800394_21-sportishka-com-p-niva-taiga-novaya-krasivo-foto-33.jpg
# Успешно №171 из 181: 6f8f0404k3d7-960.jpg from https://a.d-cd.net/6f8f0404k3d7-960.jpg
# Успешно №172 из 181: a_b40615e4.jpg from https://sun9-65.userapi.com/c937/u91597859/a_b40615e4.jpg
# Успешно №173 из 181: 363963-lada-niva-9.jpg from https://img.razrisyika.ru/kart/91/363963-lada-niva-9.jpg
# Успешно №174 из 181: 145004.843223.5164.jpeg from https://img01.rl0.ru/29e1add4ea3b9d400b2f19f74b435149/e600x400o-x0i/news.rambler.ru/img/2020/04/03/145004.843223.5164.jpeg
# Успешно №175 из 181: vaz_niva_1994_photos_1_1024x768.jpg from https://img.favcars.com/vaz/niva/vaz_niva_1994_photos_1_1024x768.jpg
# Успешно №176 из 181: Pdxiyftum4bFuVsw7jTZZIiP8dw-960.jpg from https://a.d-cd.net/Pdxiyftum4bFuVsw7jTZZIiP8dw-960.jpg
# Успешно №177 из 181: original.jpg from https://mtdata.ru/u1/photo9A09/20843092191-0/original.jpg
# Успешно №178 из 181: 1702021199_sportishka-com-p-krasivie-nivi-krasivo-1.jpg from https://sportishka.com/uploads/posts/2023-12/1702021199_sportishka-com-p-krasivie-nivi-krasivo-1.jpg
# Успешно №179 из 181: 349864_5c6c1f13142d35c6c1f131430e.jpeg from https://st03.kakprosto.ru/images/article/2019/2/19/349864_5c6c1f13142d35c6c1f131430e.jpeg
# Успешно №180 из 181: sddefault.jpg from https://i.ytimg.com/vi/BhhetbUw2_A/sddefault.jpg
# Успешно №181 из 181: 0a8c90ec26a3cb264138366ccb0b64d7a3a7ed93.jpg from https://motor.ru/imgs/2023/06/03/20/5929582/0a8c90ec26a3cb264138366ccb0b64d7a3a7ed93.jpg
#
# Качалось 00 часов 04 минут 02 секунд
#
# Количество ссылок:
# изначально - 242
# уникальных - 181
#
#
# В папке "Yandex" лежит 156 файлов

# %%
# ОБРАБОТКА ПАПКИ С ФАЙЛАМИ

# Проверяем, все ли файлы = img, переименовываем в соотв с размером ------------
files_list = []
for file in os.listdir(path):
  file_path = os.path.join(path, file)
  files_list.append(file_path)

i = 1
for file in files_list:
    try:
        with Image.open(file) as img:
            width, height = img.size
            filename, ext = os.path.splitext(os.path.basename(file))
            # тут я ограничиваю имя файла 20 символами после {width}x{height}_
            new_filename = f'{width}x{height}_{filename[:16-len(str(width))-len(str(height))-1].strip("_")}{ext}' if len(filename) > 20 else f'{width}x{height}_{filename}{ext}'
            new_file = os.path.join(path, new_filename)
            os.rename(file, new_file)
            files_list[i-1] = new_file  # Обновляем список файлов с новым именами
            #print(f'{new_filename}')
            i += 1
    except Exception as e:
        #print(f"WARNING: Файл {file} не является изображением или поврежден ({str(e)})")
        continue

# Удаляем некондиционные файлы -------------------------------------------------
num_deleted = 0

for file in os.listdir(path):
  if not re.match(r'^\d+x\d+_', file):
    file_path = os.path.join(path, file)
    os.remove(file_path)
    num_deleted += 1
print(f'\nУдалено {num_deleted} файлов')
print(f'\nВ папке "{perem_eng}" осталось {num_files - num_deleted} файлов')


# Копируем файлы в новую папку по условию --------------------------------------
new_path = os.path.join('/content', perem_eng)
paps = ['Small_less_500px', 'Middle_500-2000px', 'Big_over_2000px']
# создаем три подпапки в новой папке, куда копировать
for p in paps:
    os.makedirs(os.path.join(new_path, p), exist_ok=True)

for file in os.listdir(path):
    match = re.match(r'^(\d+)x(\d+)_.*$', file)
    if match:
        width = int(match.group(1))
        height = int(match.group(2))

        # переместить файл в нужную папку или удалить---------------------------
        if width > 4000 or height > 4000:
            os.remove(os.path.join(path, file))
        elif width < 500 or height < 500:
            shutil.copy(os.path.join(path, file), os.path.join(new_path, 'Small_less_500px'))
        elif width >= 500 and width <= 2000 and height >= 500 and height <= 2000:
            shutil.copy(os.path.join(path, file), os.path.join(new_path, 'Middle_500-2000px'))
        elif width > 2000 or height > 2000:
            shutil.copy(os.path.join(path, file), os.path.join(new_path, 'Big_over_2000px'))

# Зазиповать всю папку с подпапками---------------------------------------------
x = shutil.make_archive(new_path, 'zip', new_path)

size_bytes = os.path.getsize(f'{perem_eng}.zip')
size_mb = size_bytes / (1024 * 1024)

print(f'\nZip получен по пути {x}')
print(f"\nЗазипованный файл весит {size_mb:.2f} MB.")
print()

from google.colab import files
zip_path = os.path.join('/content', f'{perem_eng}.zip')
if os.path.exists(zip_path):
    files.download(zip_path)
print(f"Зазипованный файл скачался успешно")
# Out:
# Удалено 25 файлов
#
# В папке "Yandex" осталось 131 файлов
#
# Zip получен по пути /content/Yandex.zip
#
# Зазипованный файл весит 46.68 MB.
# Зазипованный файл скачался успешно
